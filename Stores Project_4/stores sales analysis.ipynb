# %%
# !pip install pandas 
# !pip install numpy
# !pip install plotly
# !pip install seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\kaila\appdata\local\programs\python\python310\lib\site-packages (1.4.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\kaila\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\kaila\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kaila\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\kaila\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# WARNING: You are using pip version 21.2.3; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\kaila\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: numpy in c:\users\kaila\appdata\local\programs\python\python310\lib\site-packages (1.23.1)
# WARNING: You are using pip version 21.2.3; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\kaila\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: plotly in c:\users\kaila\appdata\local\programs\python\python310\lib\site-packages (5.9.0)
# WARNING: You are using pip version 21.2.3; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\kaila\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\kaila\appdata\local\programs\python\python310\lib\site-packages (from plotly) (8.0.1)
# Requirement already satisfied: seaborn in c:\users\kaila\appdata\local\programs\python\python310\lib\site-packages (0.11.2)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\kaila\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\kaila\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.23.1)
# Requirement already satisfied: scipy>=1.0 in c:\users\kaila\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.8.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\kaila\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.4.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kaila\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (9.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kaila\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (4.34.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kaila\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kaila\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kaila\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\kaila\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\kaila\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kaila\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\kaila\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# WARNING: You are using pip version 21.2.3; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\kaila\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd 
import numpy as np 
import plotly.express as px 
import seaborn as sns
import missingno as msno
import os

# %%
df = pd.read_csv("C:\\Users\\kaila\\Desktop\\Stores.csv")

# %%
df
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0            1        1659             1961                   530        66490
# 1            2        1461             1752                   210        39820
# 2            3        1340             1609                   720        54010
# 3            4        1451             1748                   620        53730
# 4            5        1770             2111                   450        46620
# ..         ...         ...              ...                   ...          ...
# 891        892        1582             1910                  1080        66390
# 892        893        1387             1663                   850        82080
# 893        894        1200             1436                  1060        76440
# 894        895        1299             1560                   770        96610
# 895        896        1174             1429                  1110        54340
#
# [896 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Store ID              896 non-null    int64
#  1   Store_Area            896 non-null    int64
#  2   Items_Available       896 non-null    int64
#  3   Daily_Customer_Count  896 non-null    int64
#  4   Store_Sales           896 non-null    int64
# dtypes: int64(5)
# memory usage: 35.1 KB

# %%
df.head()
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0          1        1659             1961                   530        66490
# 1          2        1461             1752                   210        39820
# 2          3        1340             1609                   720        54010
# 3          4        1451             1748                   620        53730
# 4          5        1770             2111                   450        46620

# %%
df.isnull().sum()
# Out:
# Store ID                0
# Store_Area              0
# Items_Available         0
# Daily_Customer_Count    0
# Store_Sales             0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 891    False
# 892    False
# 893    False
# 894    False
# 895    False
# Length: 896, dtype: bool

# %%
df.describe()
# Out:
#         Store ID    Store_Area  Items_Available  Daily_Customer_Count  \
# count  896.000000   896.000000       896.000000            896.000000
# mean   448.500000  1485.409598      1782.035714            786.350446
# std    258.797218   250.237011       299.872053            265.389281
# min      1.000000   775.000000       932.000000             10.000000
# 25%    224.750000  1316.750000      1575.500000            600.000000
# 50%    448.500000  1477.000000      1773.500000            780.000000
# 75%    672.250000  1653.500000      1982.750000            970.000000
# max    896.000000  2229.000000      2667.000000           1560.000000
#
#          Store_Sales
# count     896.000000
# mean    59351.305804
# std     17190.741895
# min     14920.000000
# 25%     46530.000000
# 50%     58605.000000
# 75%     71872.500000
# max    116320.000000

# %%
df['Total_Monthly_Customers_Count'] = df['Daily_Customer_Count'] * 30
df['Avg_Customer_Spend_Day'] = df['Store_Sales'] / df['Total_Monthly_Customers_Count']
df['Avg_Customer_Spend_Month'] = df['Store_Sales'] / df['Daily_Customer_Count']
df['Avg_Daily_Sales'] = df['Store_Sales'] / 30

# %%
df.head()
# Out:
#    Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales  \
# 0          1        1659             1961                   530        66490
# 1          2        1461             1752                   210        39820
# 2          3        1340             1609                   720        54010
# 3          4        1451             1748                   620        53730
# 4          5        1770             2111                   450        46620
#
#    total_monthly_customers_count  avg_customer_spend_day  \
# 0                          15900                4.181761
# 1                           6300                6.320635
# 2                          21600                2.500463
# 3                          18600                2.888710
# 4                          13500                3.453333
#
#    avg_customer_spend_month  avg_daily_sales  Total_Monthly_Customers_Count  \
# 0                125.452830      2216.333333                          15900
# 1                189.619048      1327.333333                           6300
# 2                 75.013889      1800.333333                          21600
# 3                 86.661290      1791.000000                          18600
# 4                103.600000      1554.000000                          13500
#
#    Avg_Customer_Spend_Day  Avg_Customer_Spend_Month  Avg_Daily_Sales
# 0                4.181761                125.452830      2216.333333
# 1                6.320635                189.619048      1327.333333
# 2                2.500463                 75.013889      1800.333333
# 3                2.888710                 86.661290      1791.000000
# 4                3.453333                103.600000      1554.000000

# %%
import matplotlib.pyplot as plt
df.Daily_Customer_Count.hist(bins = 50, figsize=(12,8))
plt.show()

# %%
df.hist(figsize=(12,8));
plt.grid(False)

# %%
correlation = df.corr()
print(correlation['Store_Sales'].sort_values(ascending = False),'\n')
# Out:
# avg_daily_sales                  1.000000
# Avg_Daily_Sales                  1.000000
# Store_Sales                      1.000000
# avg_customer_spend_day           0.139546
# Avg_Customer_Spend_Day           0.139546
# avg_customer_spend_month         0.139546
# Avg_Customer_Spend_Month         0.139546
# Items_Available                  0.098849
# Store_Area                       0.097474
# Store ID                         0.071486
# Daily_Customer_Count             0.008629
# total_monthly_customers_count    0.008629
# Total_Monthly_Customers_Count    0.008629
# Name: Store_Sales, dtype: float64

# %%
k= 10
cols = correlation.nlargest(k,'Store_Sales')['Store_Sales'].index
print(cols)
cm = np.corrcoef(df[cols].values.T)
f , ax = plt.subplots(figsize = (14,12))
sns.heatmap(cm, vmax=.8, linewidths=0.01,square=True,annot=True,cmap="YlGnBu" ,
 linecolor="b",xticklabels = cols.values ,annot_kws = {'size':12},yticklabels = cols.values)
plt.show()
# Out:
# Index(['avg_daily_sales', 'Avg_Daily_Sales', 'Store_Sales',
#        'avg_customer_spend_day', 'Avg_Customer_Spend_Day',
#        'avg_customer_spend_month', 'Avg_Customer_Spend_Month',
#        'Items_Available', 'Store_Area', 'Store ID '],
#       dtype='object')

# %%
Yfac = df["Store_Sales"]
Xfac = df["Daily_Customer_Count"]
plt.figure(figsize=(12,8))
plt.scatter(Xfac,Yfac,s=15)
plt.xlabel('Count of Customers')
plt.ylabel('Sales in $')
plt.title('Customers & Sales of All Stores')
plt.xlim(200, 2000)
plt.yscale("linear")
plt.grid(True)

# %%
x = df[['Items_Available']]
y = df[['Store_Sales']]
_ = plt.figure(figsize=(12,8))  
_ = plt.scatter(x , y)
_ = plt.xlabel('Items Available')
_ = plt.ylabel('Sales')
_ = plt.xticks(np.arange(0, 2800 , step = 200)) 
_ = plt.yticks(np.arange(0 ,120000 , step = 20000), ['20K' , '40K' , '60K' , '80K' , '100K' , '120K']) 

plt.plot()
# Out:
# []

# %%
df.sort_values('Store_Sales', ascending=False)
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  \
# 649        650        1989             2414                   860
# 868        869        1775             2104                   980
# 432        433        1365             1638                   680
# 408        409        1303             1587                  1310
# 758        759        1486             1758                   820
# ..         ...         ...              ...                   ...
# 352        353        1397             1686                   850
# 593        594        1624             1946                   870
# 775        776        1537             1877                   660
# 852        853        1477             1790                   880
# 31          32        1250             1508                   990
#
#      Store_Sales  total_monthly_customers_count  avg_customer_spend_day  \
# 649       116320                          25800                4.508527
# 868       105150                          29400                3.576531
# 432       102920                          20400                5.045098
# 408       102310                          39300                2.603308
# 758       101820                          24600                4.139024
# ..           ...                            ...                     ...
# 352        21300                          25500                0.835294
# 593        20270                          26100                0.776628
# 775        17670                          19800                0.892424
# 852        16370                          26400                0.620076
# 31         14920                          29700                0.502357
#
#      avg_customer_spend_month  avg_daily_sales  Total_Monthly_Customers_Count  \
# 649                135.255814      3877.333333                          25800
# 868                107.295918      3505.000000                          29400
# 432                151.352941      3430.666667                          20400
# 408                 78.099237      3410.333333                          39300
# 758                124.170732      3394.000000                          24600
# ..                        ...              ...                            ...
# 352                 25.058824       710.000000                          25500
# 593                 23.298851       675.666667                          26100
# 775                 26.772727       589.000000                          19800
# 852                 18.602273       545.666667                          26400
# 31                  15.070707       497.333333                          29700
#
#      Avg_Customer_Spend_Day  Avg_Customer_Spend_Month  Avg_Daily_Sales
# 649                4.508527                135.255814      3877.333333
# 868                3.576531                107.295918      3505.000000
# 432                5.045098                151.352941      3430.666667
# 408                2.603308                 78.099237      3410.333333
# 758                4.139024                124.170732      3394.000000
# ..                      ...                       ...              ...
# 352                0.835294                 25.058824       710.000000
# 593                0.776628                 23.298851       675.666667
# 775                0.892424                 26.772727       589.000000
# 852                0.620076                 18.602273       545.666667
# 31                 0.502357                 15.070707       497.333333
#
# [896 rows x 13 columns]
